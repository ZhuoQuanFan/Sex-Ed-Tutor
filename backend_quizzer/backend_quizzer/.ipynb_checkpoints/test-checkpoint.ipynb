# %%
from elasticsearch import Elasticsearch
import numpy as np
from datetime import datetime
es = Elasticsearch('http://localhost:9200')
import json
import time
import copy
import csv
import re
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
nltk.download('punkt')

# try:
#     print('try to create an index')
#     es.indices.create(index='question_pool_all', ignore=400)
#     print('Create the index succesffuly.')
# except:
#     print('error')
# # es.indices.delete(index='question_pool_all', ignore=[400, 404])
# print('Recreating the index.')
# es.indices.create(index='question_pool_all', ignore=400)
# print('Do not rebuild the dataset, it takes hours.')

start_time = time.time()
count = 1
with open('./question_base/pool2(feedback_request_post_comments).json', 'rb') as f:
    items = json.load(f)
    items_length = len(items)
# Out:
# [nltk_data] Downloading package punkt to /Users/zhenhui/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
store_items = []
for item in items[30:45]:
    for question in item['questions']:
        # if 'other_options_wiki' in question.keys():
        store_item = copy.deepcopy(item)
        # print(question)
        store_item['questions'] = ''
        store_item['question_id:'] = question['question_id:']
        store_item['raw_critique'] = question['raw_critique']
        store_item['select_design_concept'] = question['select_design_concept']
        store_item['mention_ui_elements'] = question['mention_ui_elements']
        store_item['question'] = question['question']
        store_item['right_answer'] = question['right_answer']
        store_item['explanation'] = question['explanation']
        # store_item['other_options'] = question['other_options']
        # store_item['other_options_wiki'] = question['other_options_wiki']
        
        store_item['ui_elements'] = ''
        for ui_element in question['mention_ui_elements']:
            store_item['ui_elements'] += ui_element['name']

        # new structure 20220820
        store_item['answer_cluster'] = question['select_design_concept']['cluster']
        store_item['answer_pos_tag'] = question['select_design_concept']['pos_tag']
        store_item['other_option_1'] = question['other_options'][0]
        store_item['other_option_2'] = question['other_options'][1]

        explanation = question['explanation']
        text = question['question']
        right_answer = question['right_answer']
        len_blank = len(right_answer)
        replaced_term = '_'*len_blank
        critique = text.replace(replaced_term, right_answer)
        find_critique = critique[:-1]
        store_item['question'] = text.replace(replaced_term, '____')
        
        
        critique_index_start = explanation.find(critique)
        critique_index_end = critique_index_start + len(critique)
#         print(critique_index_start)
#         print(critique_index_end)
# #         print(explanation)
#         print(explanation[critique_index_start:critique_index_end])

        hint = '\"<b>' + store_item['question'] + '</b>\"'
        explanation = '\"<b>' + store_item['question'] + '</b>\"'
    
        comment = {}
        comment_raw = ''
        for comment_temp in item['comments']:
            comment_summary = comment_temp['comment_summary']
#             print('*******')
#             print(comment_summary)
#             print(critique)
            temp = [index for (index , item) in enumerate(sent_tokenize(comment_summary)) if (find_critique.find(item.split('.')[0]) >= 0 or find_critique.find(item.split('?')[0]) >= 0 or find_critique.find(item.split('!')[0]) >= 0 or find_critique.find(item.split(';')[0]) >= 0)]
            if len(temp) > 0:
                comment_raw = comment_temp['comment_raw']
                comment = comment_temp
                break
        
        # 删除bot留下的comment
        if 'Welcome to UI Design.' in comment_raw:
            continue

            
        # 定位critique在comment_summary中的位置。
        raw_sentences =  sent_tokenize(comment_raw)
        summary_sentences =  sent_tokenize(comment_summary)
        critique_index = [index for (index , item) in enumerate(summary_sentences) if 
                          (critique.find(item.split('.')[0]) >= 0 or critique.find(item.split('?')[0]) >= 0 
                            or critique.find(item.split('!')[0]) >= 0 or critique.find(item.split(';')[0]) >= 0
                            or item.find(find_critique) >= 0
                           )]
#         print(critique_index)
#         print(summary_sentences)
        critique_in_raw = [index for (index , item) in enumerate(raw_sentences) if 
                           (critique.find(item.split('.')[0]) >= 0 or critique.find(item.split('?')[0]) >= 0 
                            or critique.find(item.split('!')[0]) >= 0 or critique.find(item.split(';')[0]) >= 0
                            or item.find(find_critique) >= 0
                           )]
#         print(critique_in_raw)
#         print(raw_sentences)
#         print('#'*30)
#         print('comment_summary: {}'.format(comment_summary))
#         print('comment_raw: {}'.format(comment_raw))
#         print('critique: {}'.format(critique))
# #         print(comment)
#         print(critique_index)
#         print(critique_in_raw)
        if comment == {} or len(critique_index) == 0 or len(critique_in_raw) == 0:
            continue
        
        critique_in_comment = []
        raw_critique_in_comment = []
        suggestion_in_comment = [] #
        raw_suggestion_in_comment = []
        rationale_in_comment = []
        raw_rationale_in_comment = []
        for i in range(len(comment['critique'])):
            sentence = comment['critique'][i]['sentence']
            raw_critique_in_comment.append(sentence)
            sentence = '<font color="#000000">' + sentence + '</font>'
            for j in range(len(comment['critique'][i]['ui_elements'])):
                name = comment['critique'][i]['ui_elements'][j]['name']
                if name != 'color':
                    sentence = sentence.replace(name, '<font color="#660000">' + name + '</font>', 1)
            for j in range(len(comment['critique'][i]['concepts'])):
                name = comment['critique'][i]['concepts'][j]['name']
                if name != 'color':
                    sentence = sentence.replace(name, '<font color="#660099">' + name + '</font>', 1)
            critique_in_comment.append(sentence)
        for i in range(len(comment['suggestion'])):
            sentence = comment['suggestion'][i]['sentence']
            raw_suggestion_in_comment.append(sentence)
            sentence = '<font color="#2F3756">' + sentence + '</font>'
            for j in range(len(comment['suggestion'][i]['ui_elements'])):
                name = comment['suggestion'][i]['ui_elements'][j]['name']
                if name != 'color':
                    sentence = sentence.replace(name, '<font color="#660000">' + name + '</font>', 1)
            for j in range(len(comment['suggestion'][i]['concepts'])):
                name = comment['suggestion'][i]['concepts'][j]['name']
                if name != 'color':
                    sentence = sentence.replace(name, '<font color="#660099">' + name + '</font>', 1)
            suggestion_in_comment.append(sentence)
        for i in range(len(comment['rationale'])):
            sentence = comment['rationale'][i]['sentence']
            raw_rationale_in_comment.append(sentence)
            sentence = '<font color="#CC0000">' + sentence + '</font>'
            for j in range(len(comment['rationale'][i]['ui_elements'])):
                name = comment['rationale'][i]['ui_elements'][j]['name']
                if name != 'color':
                    sentence = sentence.replace(name, '<font color="#660000">' + name + '</font>', 1)
            for j in range(len(comment['rationale'][i]['concepts'])):
                name = comment['rationale'][i]['concepts'][j]['name']
                if name != 'color':
                    sentence = sentence.replace(name, '<font color="#660099">' + name + '</font>', 1)
            rationale_in_comment.append(sentence)
        
        if len(critique_index) > 0:
            locate_index = critique_in_raw[0]
            if locate_index == 0: 
                if len(raw_sentences) > 1:
                    hint_add = raw_sentences[critique_in_raw[0]+1]
#                     print('*********')
#                     print(hint_add)
#                     print(raw_sentences)
#                     print(raw_critique_in_comment)
#                     print(raw_suggestion_in_comment)
#                     print(raw_rationale_in_comment)
                    temp1 = [index for (index , item) in enumerate(raw_critique_in_comment) if hint_add.find(item) >= 0]
                    temp2 = [index for (index , item) in enumerate(raw_suggestion_in_comment) if hint_add.find(item) >= 0]
                    temp3 = [index for (index , item) in enumerate(raw_rationale_in_comment) if hint_add.find(item) >= 0]
                    if len(temp1) > 0:
                        hint_add = ' (critique) ' + critique_in_comment[temp1[0]]
                    elif len(temp2) > 0:
                        hint_add = ' (suggestion) ' + suggestion_in_comment[temp2[0]]
                    elif len(temp3) > 0:
                        hint_add = ' (rationale) ' + rationale_in_comment[temp3[0]]
                    hint = hint + hint_add
            else:
                hint_add = raw_sentences[critique_in_raw[0]-1]
                temp1 = [index for (index , item) in enumerate(raw_critique_in_comment) if hint_add.find(item) >= 0]
                temp2 = [index for (index , item) in enumerate(raw_suggestion_in_comment) if hint_add.find(item) >= 0]
                temp3 = [index for (index , item) in enumerate(raw_rationale_in_comment) if hint_add.find(item) >= 0]
                if len(temp1) > 0:
                    hint_add = ' (critique) ' + critique_in_comment[temp1[0]]
                elif len(temp2) > 0:
                    hint_add = ' (suggestion) ' + suggestion_in_comment[temp2[0]]
                elif len(temp3) > 0:
                    hint_add = ' (rationale) ' + rationale_in_comment[temp3[0]]
                hint = hint_add + hint
#                 print(len(raw_sentences))
#                 print(locate_index)
#                 print(critique_in_raw[0])
                if len(raw_sentences) - locate_index > 1:
                    hint_add = raw_sentences[locate_index+1]
                    temp1 = [index for (index , item) in enumerate(raw_critique_in_comment) if hint_add.find(item) >= 0]
                    temp2 = [index for (index , item) in enumerate(raw_suggestion_in_comment) if hint_add.find(item) >= 0]
                    temp3 = [index for (index , item) in enumerate(raw_rationale_in_comment) if hint_add.find(item) >= 0]
                    if len(temp1) > 0:
#                         print(critique_in_comment)
#                         print(raw_critique_in_comment)
                        hint_add = ' (critique) ' + critique_in_comment[temp1[0]]
                    elif len(temp2) > 0:
                        hint_add = ' (suggestion) ' + suggestion_in_comment[temp2[0]]
                    elif len(temp3) > 0:
                        hint_add = ' (rationale) ' + rationale_in_comment[temp3[0]]
                    
                    hint = hint + hint_add
                
#         print(raw_sentences)
        print('hint: {}'.format(hint))
       
        explanation = ''
        print(comment_summary)
        for sen in summary_sentences:
            temp1 = [index for (index , item) in enumerate(raw_critique_in_comment) if item.find(sen) >= 0]
            temp2 = [index for (index , item) in enumerate(raw_suggestion_in_comment) if item.find(sen) >= 0]
            temp3 = [index for (index , item) in enumerate(raw_rationale_in_comment) if item.find(sen) >= 0]
            if len(temp1) > 0:
                hint_add = ' <b>(critique)</b> ' + critique_in_comment[temp1[0]]
                if critique.find(sen) >= 0:
                    hint_add = '\"<b>' + hint_add + '</b>\"'
                explanation += hint_add
            elif len(temp2) > 0:
                hint_add = ' <b>(suggestion)</b> ' + suggestion_in_comment[temp2[0]]
                explanation += hint_add
            elif len(temp3) > 0:
                hint_add = ' <b>(rationale)</b> ' + rationale_in_comment[temp3[0]]
                explanation += hint_add
#         print(summary_sentences)
#         print(raw_critique_in_comment)
#         print(raw_suggestion_in_comment)
#         print(raw_rationale_in_comment)
#         print(comment_summary)
#         print(explanation)
        explanation = explanation + '\nFor more about this UI example, please check this <a href=\"' + item['post_url'] + '\" target="_blank">link</a>.'
        store_item['explanation'] = explanation
        store_item['hint'] = hint
        store_items.append(store_item)
        
        # es.index(index='question_pool', body=store_item)
        # print(doc)
        count += 1
        if count % 100 == 0:
            print('Insert {}/{} palettes: take {}s'.format(count, items_length, round(time.time() - start_time, 2)))
    # if count == 401:
        #     break
# Out:
# hint: "<b>a bit ____ I'd say but overall good.</b>"One thing though; negative space.Space between the sections, space between text and boxes, space in general.
# ['It looks kind of pushed together from all side.', "a bit inconsistent I'd say but overall good.", 'negative space.Space between the sections, space between text and boxes, space in general.']
# hint: Hey OP, this is a GOOD starting design!"<b>I really like the ____ and (to me) the woman looks okay since her background matches the general color scheme.</b>" (suggestion) <font color="#2F3756">Maybe switch the <font color="#660000">H1</font> to <font color="#660000">"Get serious about digital marketing"</font> so it can match her facial expression as others have suggested.</font>
# ['I really like the colors and (to me) the woman looks okay since her background matches the general color scheme.', 'Maybe switch the H1 to "Get serious about digital marketing" so it can match her facial expression as others have suggested.', 'Remove both the "grow your business" and the button underneath it2 remove the "increase sales" button &amp; icon and the "reach customers" button &amp; iconYour homepage will look 10x better.']
# hint: "<b>I t____ most of the comments here have mentioned the lack of hierachical structures and the many buttons.</b>"My opinion is that find a more neutral shades for different texts.
# ['I think most of the comments here have mentioned the lack of hierachical structures and the many buttons.', 'find a more neutral shades for different texts.']
# hint: "<b>At this point it simply lacks a cohesive structure and ____ hence it appears chaotic at best.</b>"What's the primary action on this page?
# ['At this point it simply lacks a cohesive structure and hierarchy, hence it appears chaotic at best.', "There are blocks hanging loosely to the right of the model — they completely ruin the layout.There's too much text in the description and I can spot an unnecessary secondary heading in bold.", "It doesn't help the user to understand what your site is about.", 'Just state what the company is about without extra clutter.It would be best if you revised the information architecture on the page and grouped it into digestible blocks, one per screen.', 'Title + short description + header menu2) Services3) etc.', 'At this point it simply lacks a cohesive structure and hierarchy, hence it appears chaotic at best.', 'There are blocks hanging loosely to the right of the model — they completely ruin the layout.', "There's too much text in the description and I can spot an unnecessary secondary heading in bold.", "It doesn't help the user to understand what your site is about."]
# hint: What's the secondary?"<b>There are blocks hanging loosely to the right of the model — they completely ruin the ____ too much text in the description and I can spot an unnecessary secondary heading in bold.</b>" (critique) <font color="#000000">There's too much text in the description and I can spot an unnecessary secondary <font color="#660000">heading</font> in <font color="#660000">bold</font>.</font>
# ['At this point it simply lacks a cohesive structure and hierarchy, hence it appears chaotic at best.', "There are blocks hanging loosely to the right of the model — they completely ruin the layout.There's too much text in the description and I can spot an unnecessary secondary heading in bold.", "It doesn't help the user to understand what your site is about.", 'Just state what the company is about without extra clutter.It would be best if you revised the information architecture on the page and grouped it into digestible blocks, one per screen.', 'Title + short description + header menu2) Services3) etc.', 'At this point it simply lacks a cohesive structure and hierarchy, hence it appears chaotic at best.', 'There are blocks hanging loosely to the right of the model — they completely ruin the layout.', "There's too much text in the description and I can spot an unnecessary secondary heading in bold.", "It doesn't help the user to understand what your site is about."]
# hint: "<b>At this point it simply lacks a cohesive structure and ____ hence it appears chaotic at best.</b>"What's the primary action on this page?
# ['At this point it simply lacks a cohesive structure and hierarchy, hence it appears chaotic at best.', "There are blocks hanging loosely to the right of the model — they completely ruin the layout.There's too much text in the description and I can spot an unnecessary secondary heading in bold.", "It doesn't help the user to understand what your site is about.", 'Just state what the company is about without extra clutter.It would be best if you revised the information architecture on the page and grouped it into digestible blocks, one per screen.', 'Title + short description + header menu2) Services3) etc.', 'At this point it simply lacks a cohesive structure and hierarchy, hence it appears chaotic at best.', 'There are blocks hanging loosely to the right of the model — they completely ruin the layout.', "There's too much text in the description and I can spot an unnecessary secondary heading in bold.", "It doesn't help the user to understand what your site is about."]
# hint: Definitely less buttons."<b>The ____ is super strong as well..</b>"
# ['The gradient is super strong as well.']
# hint: This!"<b>Everything seems like a CTA, also the ____ on the buttons look outdated at best.</b>"
# ['Everything seems like a CTA, also the gradient on the buttons look outdated at best']
# hint: "<b>____ is your biggest issue here.</b>" (suggestion) <font color="#2F3756">You can create that by allowing your design to breath more with <font color="#660099">white space</font> and adjusting your <font color="#660099">font choice</font>.</font>
# ['Hierarchy is your biggest issue here.', 'You can create that by allowing your design to breath more with white space and adjusting your font choice.', 'You can also play around with color contrast from your header and body copy.']
# hint: "<b>The lady looks like a karen calling the cops on your ____ buttons.</b>"
# ['The lady looks like a karen calling the cops on your gradient buttons']
# hint: "<b>I'm terrible at ____ writing.</b>"Or just writing in general :|
# ["I'm terrible at copy writing.", 'Or just writing in general :|']
# hint: Also if all priorities are the same you should look at another way to present all options, like a card."<b>Also the ____ blue black gradient is pretty intense.</b>"Looks like a pop up scam site.
# ['The way you’ve presented the CTA buttons is bad.', 'All the same priority which doesn’t help the customer prioritise an action.', 'Also the dark blue black gradient is pretty intense.', 'Looks like a pop up scam site.']
# hint:  (suggestion) <font color="#2F3756">For screen one, it needs a stronger <font color="#660099">signifier</font>.</font>"<b>The ____ green arrow is not easily seen.</b>" (suggestion) <font color="#2F3756">For screen two, use similar <font color="#660099">icon styles</font> for all google, fb, and Twitter.</font>
# ['You can also further develop the typography or even give the headings more weight.', 'For screen one, it needs a stronger signifier.', 'The light green arrow is not easily seen.', 'For screen two, use similar icon styles for all google, fb, and Twitter.', 'Google is the outlier.', 'For screen three, I understand it’s a medical app but the red plus button appears like I would click on it for emergency services']
# hint: This is a good start, but I suggest you take more time to pair the colors."<b>The ____ make a huge difference.</b>"The teal you have added is not contrasting enough.
# ['The colors make a huge difference.', 'The teal you have added is not contrasting enough.']
# hint:  (critique) <font color="#000000">The <font color="#660099">colors</font> make a huge difference.</font>"<b>The teal you have added is not ____ enough..</b>"
# ['The colors make a huge difference.', 'The teal you have added is not contrasting enough.']
# hint:  (suggestion) <font color="#2F3756">We require a minimum <font color="#660099">account age</font> and karma before posting in our <font color="#660000">sub</font>.</font>"<b>These ____ are not disclosed to help reduce spam and other issues.</b>" (rationale) <font color="#CC0000">You can gain karma by being active in the <font color="#660000">sub</font>.</font>
# ['We require a minimum account age and karma before posting in our sub.', 'These minimums are not disclosed to help reduce spam and other issues.', 'You can gain karma by being active in the sub.', 'Do not contact the mods asking for an exemption or to bypass the rules.', 'I am a bot, and this action was performed automatically.', 'Please only contact the moderators of this subreddit if you have any concerns.']
# hint: Hi thanks a lot for your feedback!"<b>How do you think about ____ with white text for the store text.</b>"I was also trying out some more prominent drop shadows, do you think it looks alright?
# ['How do you think about red with white text for the store text?', 'I was also trying out some more prominent drop shadows, do you think it looks alright?']
# hint: This is a great concept!"<b>All relevant information in regards to UX and ____ has been considered nicely and my eye is drawn to the right bits and intuitively I think I would tap where you want me to.</b>"My only additional feedback would be perhaps to use a different colour other than red / light red for Saving 20% in Store text and background tags, just to let them jump out a bit.
# ['All relevant information in regards to UX and hierarchy has been considered nicely and my eye is drawn to the right bits and intuitively I think I would tap where you want me to.', 'My only additional feedback would be perhaps to use a different colour other than red / light red for Saving 20% in Store text and background tags, just to let them jump out a bit.']
# hint: 3."<b>Nothing is full ____ except the nav bar which might not be an actual problem but I don’t like it.</b>"I don’t like how the page where the form is also less wide than all the other contents even though I know the form can look better if it’s relatively narrow.
# ["The submit button on the last screen should be the right one or at least the back button should not be emphasized as much (and it shouldn't have a caret-right icon).", "I would align the “not required / Nem kötelez” text to the right but I can’t really tell you why, maybe because it's repeating content which doesn’t start at the same position.", 'Nothing is full width except the nav bar which might not be an actual problem but I don’t like it.', 'The FAQ is also less wide than the one above it but it still begins at the same x position.', 'The FAQ is also less wide than the one above it but it still begins at the same x position.', 'I would make that section’s background white or would make the text darker.', 'The logo in the footer is the same logo as in the nav but for some reason it doesn’t have enough contrast in my opinion.', 'I would make that section’s background white or would make the text darker.', 'TI’s not a large problem obviously it’s just weird.', 'I would make that section’s background white or would make the text darker.', 'TThe logo in the footer is the same logo as in the nav but it still begins at the same x position.']
# hint: I don’t like how the page where the form is also less wide than all the other contents even though I know the form can look better if it’s relatively narrow."<b>The FAQ is also ____ wide than the one above it but it still begins at the same x position.</b>"4.
# ["The submit button on the last screen should be the right one or at least the back button should not be emphasized as much (and it shouldn't have a caret-right icon).", "I would align the “not required / Nem kötelez” text to the right but I can’t really tell you why, maybe because it's repeating content which doesn’t start at the same position.", 'Nothing is full width except the nav bar which might not be an actual problem but I don’t like it.', 'The FAQ is also less wide than the one above it but it still begins at the same x position.', 'The FAQ is also less wide than the one above it but it still begins at the same x position.', 'I would make that section’s background white or would make the text darker.', 'The logo in the footer is the same logo as in the nav but for some reason it doesn’t have enough contrast in my opinion.', 'I would make that section’s background white or would make the text darker.', 'TI’s not a large problem obviously it’s just weird.', 'I would make that section’s background white or would make the text darker.', 'TThe logo in the footer is the same logo as in the nav but it still begins at the same x position.']
# hint: I don’t like how the page where the form is also less wide than all the other contents even though I know the form can look better if it’s relatively narrow."<b>The FAQ is also ____ wide than the one above it but it still begins at the same x position.</b>"4.
# ["The submit button on the last screen should be the right one or at least the back button should not be emphasized as much (and it shouldn't have a caret-right icon).", "I would align the “not required / Nem kötelez” text to the right but I can’t really tell you why, maybe because it's repeating content which doesn’t start at the same position.", 'Nothing is full width except the nav bar which might not be an actual problem but I don’t like it.', 'The FAQ is also less wide than the one above it but it still begins at the same x position.', 'The FAQ is also less wide than the one above it but it still begins at the same x position.', 'I would make that section’s background white or would make the text darker.', 'The logo in the footer is the same logo as in the nav but for some reason it doesn’t have enough contrast in my opinion.', 'I would make that section’s background white or would make the text darker.', 'TI’s not a large problem obviously it’s just weird.', 'I would make that section’s background white or would make the text darker.', 'TThe logo in the footer is the same logo as in the nav but it still begins at the same x position.']
# hint: What is tracking ?"<b>The ____ between the letters.</b>"In your UI design that is a bit too much.
# ['Learn about white space.', 'The buttons are not centerd.', 'The are lacking space.', 'Learn about typography.', 'What is tracking?', 'The spacing between the letters.', 'In your UI design that is a bit too much.']
# hint: Yeah, I agree."<b>Especially at the bottom with the ____ footer already.</b>"It pops significantly more against the rest of the section.
# ['Especially at the bottom with the gray-colored footer already.', 'It pops significantly more against the rest of the section.']
# hint: I'm trying to transition more into product design and UI/UX design from being a developer and I've never been able to get an interview for anything design thus far."<b>I didn't design a mobile version mainly because this was technically going to be something completely different but I just saw that teal ____ and got ideas lol.</b>" (suggestion) <font color="#2F3756">I think <font color="#660099">spacing</font> might still be an issue on the <font color="#660000">form</font> but this is what I would go for.</font>
# ['I think spacing might still be an issue on the form but this is what I would go for.', "I didn't design a mobile version mainly because this was technically going to be something completely different but I just saw that teal color and got ideas lol.", 'But I guess if I did do a mobile design, the search component would probably look something like this... [https://i.imgur.com/ppXHRHL.png](https://i.imgur.com/ppXHRHL.png) I think maybe a dropdown would be a nicer touch and would simplify the experience of the form.', 'Originally I also had the Travelers textbox as a numeric textbox as a numeric textbox in my mind but I was getting sidetracked since I was watching a show as well.', 'I think spacing might still be an issue on the form but this is what I would go for.', 'I think maybe a dropdown would be a nicer touch and would simplify the experience of the form.', "I didn't design a mobile version mainly because this was technically going to be something completely different but I just saw that teal color and got ideas lol."]
# hint: I'm trying to transition more into product design and UI/UX design from being a developer and I've never been able to get an interview for anything design thus far."<b>I didn't design a mobile version mainly because this was technically going to be something completely different but I just saw that ____ color and got ideas lol..</b>" (suggestion) <font color="#2F3756">I think <font color="#660099">spacing</font> might still be an issue on the <font color="#660000">form</font> but this is what I would go for.</font>
# ['I think spacing might still be an issue on the form but this is what I would go for.', "I didn't design a mobile version mainly because this was technically going to be something completely different but I just saw that teal color and got ideas lol.", 'But I guess if I did do a mobile design, the search component would probably look something like this... [https://i.imgur.com/ppXHRHL.png](https://i.imgur.com/ppXHRHL.png) I think maybe a dropdown would be a nicer touch and would simplify the experience of the form.', 'Originally I also had the Travelers textbox as a numeric textbox as a numeric textbox in my mind but I was getting sidetracked since I was watching a show as well.', 'I think spacing might still be an issue on the form but this is what I would go for.', 'I think maybe a dropdown would be a nicer touch and would simplify the experience of the form.', "I didn't design a mobile version mainly because this was technically going to be something completely different but I just saw that teal color and got ideas lol."]
# hint: "<b>but why are those buttons on the bottom ____ and not also blue like the rest xd?.</b>"
# ['but why are those buttons on the bottom black and not also blue like the rest xd?']
# hint: "<b>How did you make the hove____ effect.</b>"like coded i mean
# ['How did you make the hover effect?', 'like coded i mean']
# hint: "<b>I think the ____ is killing it.</b>"maybe put the "Did you know that" in a bigger title and decrease he font of "approximately..." to put it below that left aligned
# ['I think the font is killing it.', 'maybe put the "Did you know that" in a bigger title and decrease he font of "approximately..." put it below that left alignedededededededededdededdededdeddeddeddeddeddeddddddddddddddddddddddddddddddddd']
# hint: "<b>I think the colors are fine, but the ____ font makes it a little harder to read, especially when in bold.</b>" (suggestion) <font color="#2F3756">Other then that, maybe a bit more <font color="#660099">padding</font> on the <font color="#660000">navbar</font>, especially <font color="#660000">top and bottom</font>, and make sure the <font color="#660099">margins</font> with <font color="#660000">text</font> are <font color="#660099">consistent</font> in the <font color="#660000">content card</font>.</font>
# ['I think the colors are fine, but the condensed font makes it a little harder to read, especially when in bold.', 'Other then that, maybe a bit more padding on the navbar, especially top and bottom, and make sure the margins with text are consistent in the content card.', 'Also separate the paragraphs a bit so the last sentence stands out more.']
# hint:  (suggestion) <font color="#2F3756">I think <font color="#660099">green</font> would be aestgetically nice too, but it would blend more in with the <font color="#660099"><font color="#660099"><font color="#660099">blue</font></font></font> (since <font color="#660099">orange</font> is blue's complimentary color it should work with blue).</font>"<b>Is the ____ wrong colour or problems with tracking, spacing, size etc.</b>"What kind of font would be better?
# ["I think green would be aestgetically nice too, but it would blend more in with the blue (since orange is blue's complimentary color it should work with blue).", 'Is the font wrong colour or problems with tracking, spacing, size etc?', 'What kind of font would be better?']
# hint:  (suggestion) <font color="#2F3756">My goal was to make it simple and easy to use.</font>"<b>____ isn't my first language so the text is probably a bit awkward, I tried my best.</b>"I also noticed that I could have probably lowered the text a bit.
# ["It's a design for a nature concervation site specialized in the oceans.", 'MML stands for My Marine Life.', 'My goal was to make it simple and easy to use.', "English isn't my first language so the text is probably a bit awkward, I tried my best!", 'I also noticed that I could have probably lowered the text a bit.']
# hint: "<b>All the boxes have different ____ on the corners and the burger menu icon (is depreciated at this point due to its ambiguousness - think about what you want there because it shouldn't just become a garbage bin for all the functions you cannot fit in elsewhere) has different line thinkness that the other icons.</b>"Btw why did you flip the shopping trolley icon?
# ["All the boxes have different rounding on the corners and the burger menu icon (is depreciated at this point due to its ambiguousness - think about what you want there because it shouldn't just become a garbage bin for all the functions you cannot fit in elsewhere) has different line thinkness that the other icons.", 'Btw why did you flip the shopping trolley icon?', 'You have a problem with contrast.', 'Use this website to determine colors with appropriate contrast: https://contrast-ratio.com/']
# hint: "<b>I do digital art for fun and I've never understood how ____ works..</b>"And here it is, coming back to bite me 😭
# ["I do digital art for fun and I've never understood how greyscale works."]
# hint:  (suggestion) <font color="#2F3756">You need to improve the <font color="#660099">contrast</font> between <font color="#660000">text</font> and its <font color="#660099">container</font>.</font>"<b>That ____ text is completely lost against the white background.</b>" (critique) <font color="#000000">Your search is another example of this.</font>
# ['You need to improve the contrast between text and its container.', 'That pinkish text is completely lost against the white background.', 'Your search is another example of this.', 'The background is too cluttered.', 'The splotches, as others have mentioned, are drawing more attention than they should be.', 'The search feels a little bit out of place on a single product page.', 'It also needs to move a bit further down from the iPhone notch.', 'The left and right arrows are a little bit confusing.', 'Would those take me to additional product photographs or to the previous and next products?', "In their current position I'm unsure what they would do.", 'I think if you changed those points this design could really improve.', 'I like to very quickly validate my recommendations and [this is the end result](https://i.imgur.com/nwBH9Tm.png) of me trying this.']
# hint:  (critique) <font color="#000000">The <font color="#660000">background</font> is too cluttered.</font>"<b>The sp____ as others have mentioned, are drawing more attention than they should be.</b>"3.
# ['You need to improve the contrast between text and its container.', 'That pinkish text is completely lost against the white background.', 'Your search is another example of this.', 'The background is too cluttered.', 'The splotches, as others have mentioned, are drawing more attention than they should be.', 'The search feels a little bit out of place on a single product page.', 'It also needs to move a bit further down from the iPhone notch.', 'The left and right arrows are a little bit confusing.', 'Would those take me to additional product photographs or to the previous and next products?', "In their current position I'm unsure what they would do.", 'I think if you changed those points this design could really improve.', 'I like to very quickly validate my recommendations and [this is the end result](https://i.imgur.com/nwBH9Tm.png) of me trying this.']
# hint:  (suggestion) <font color="#2F3756">Somewhat like what chrome does between <font color="#660000">tab</font>s in its header.</font>"<b>It has a small thin line which is a bit smaller than the height of the tabs, and is centredd on the whole layout, I'm not sure what the technical term for it is, but maybe thin lines which do not span the entire width and ____ of the elements.</b>"
# ["It has a small thin line which is a bit smaller than the height of the tabs, and is centredd on the whole layout, I'm not sure what the technical term for it is, but maybe thin lines which do not span the entire width and breadth of the elements?", 'Somewhat like what chrome does between tabs in its header.', 'It has a small thin line which is a bit smaller than the height of the tabs,']
# hint:  (suggestion) <font color="#2F3756">Somewhat like what chrome does between <font color="#660000">tab</font>s in its header.</font>"<b>It has a small ____ line which is a bit smaller than the height of the tabs,.</b>"
# ["It has a small thin line which is a bit smaller than the height of the tabs, and is centredd on the whole layout, I'm not sure what the technical term for it is, but maybe thin lines which do not span the entire width and breadth of the elements?", 'Somewhat like what chrome does between tabs in its header.', 'It has a small thin line which is a bit smaller than the height of the tabs,']
# hint: "<b>It looks very clean, but the floating white and ____ buttons are not very accessible.</b>"Maybe try using some elevation (via shadows) and/or a different color to help distinguish them as "buttons" rather than blending into the background.
# ['It looks very clean, but the floating white and grey buttons are not very accessible.', 'Maybe try using some elevation (via shadows) and/or a different color to help distinguish them as "buttons" rather than blending into the background.']
# hint: "<b>TYour design and ____ is visually pleasing and nicely laid out.</b>"Some things that stand out to me that would be good to add (or think about) would be:- Try and show your thought process a little more, how did you get to your solution?
# ['It would be great to link your design back to your original problem statement of wanting to increase dog adoptions and stop puppy mills.', 'TYour design and presentation is visually pleasing and nicely laid out.', 'How did you determine the site map?', 'Presenting a well laid out screen design is one thing, showing the thought process behind why you’re recommending this design is another thing.', 'Demonstrating a hint of the thought process that led you to the solution helps give you creditability as a designer.', 'How did your survey results impact the design of the app?', 'Explain this to your audience.', 'How does this tie back into your problem statement of wanting to increase dog adoptions and stop puppy mills.', 'Eg.', 'Followers of your dog instagram are likely to be interested in dogs or own a dog.', 'How does your design/app solve this problem?', 'Explain this to your audience.', 'Explain this to your audience.', 'How did you determine the correct audience to survey?', 'Did you account for any potential bias in the participants surveyed?', 'Eg.', 'It would be great to link your design back to your original problem statement of wanting to increase dog adoptions and stop puppy mills.']
# hint: "<b>The ____ is too bright, otherwise looks nice!.</b>"
# ['The blue is too bright, otherwise looks nice!']
# hint: "<b>I feel like typography ____ is allover the place: button text too big, description under cards (notes) too small.Im also not sure what that whole component is supposed to be, it looks like a card with a card/table cell inside?.</b>"Im also not sure what that whole component is supposed to be, it looks like a card with a card/table cell inside?Im not of border radius size on input fields, its neither here nor there IMO but that is personal opinion.
# ['I feel like typography sizing is allover the place: button text too big, description under cards (notes) too small.Im also not sure what that whole component is supposed to be, it looks like a card with a card/table cell inside?']

# %%
with open('./question_pool_0821.json', 'w') as f:
    json_string = json.dumps(store_items)
    f.write(json_string)
